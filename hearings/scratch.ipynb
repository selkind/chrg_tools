# %%
import os
import toml
from dotenv import load_dotenv
from gpo_tools.parse import Parser


env_path = os.path.join(os.path.abspath(''), '.env')
load_dotenv(env_path)


config = toml.load(os.path.join(os.path.abspath(''), 'config.toml'))
db_config = config['database']

parser = Parser(db=db_config['name'], user=db_config['user'], password=os.getenv('DB_POSTGRES_PW'), host=db_config['host'])
# Out:
# No ID values were given, so all IDs in the database will be processed. Proceed y/(n)? 'y'

# %%
print(len(parser.id_values))
# Out:
# 200

# %%
parser.parse_gpo_hearings()
# Out:
# CHRG-112shrg65276
# assigning metadata
# CHRG-112shrg65083
# assigning metadata
# CHRG-112jhrg71179
# Warning! One of the following committees is missing from the committee data file:
# ('JOINT', 'Deficit Reduction')
# --------
# CHRG-112hhrg63873
# assigning metadata
# CHRG-112hhrg63876
# assigning metadata
# CHRG-112jhrg70859
# Warning! One of the following committees is missing from the committee data file:
# ('JOINT', 'Deficit Reduction')
# --------
# CHRG-112shrg91572
# assigning metadata
# CHRG-112jhrg95616
# assigning metadata
# CHRG-112hhrg76894
# assigning metadata
# CHRG-112shrg72308
# assigning metadata
# CHRG-112shrg64591
# assigning metadata
# CHRG-112shrg29104515
# assigning metadata
# CHRG-112shrg81638
# assigning metadata
# CHRG-112shrg74273
# assigning metadata
# CHRG-112shrg19104464
# assigning metadata
# CHRG-112hhrg72870
# assigning metadata
# CHRG-112shrg74443
# assigning metadata
# CHRG-112shrg66050
# CHRG-112shrg66052
# CHRG-112shrg66051
# CHRG-112hhrg76190
# CHRG-112hhrg71189
# CHRG-113shrg39104558
# CHRG-112hhrg71188
# CHRG-112hhrg71187
# CHRG-112hhrg71186
# CHRG-112hhrg70940
# CHRG-112hhrg74809
# assigning metadata
# CHRG-112hhrg74002
# assigning metadata
# CHRG-112hhrg78599
# assigning metadata
# CHRG-112hhrg70936
# CHRG-112hhrg73765
# CHRG-112shrg77843
# assigning metadata
# CHRG-112shrg76064
# assigning metadata
# CHRG-112hhrg66730
# assigning metadata
# CHRG-112shrg68066
# assigning metadata
# CHRG-112hhrg66865
# assigning metadata
# CHRG-112hhrg77037
# assigning metadata
# CHRG-112hhrg75312
# assigning metadata
# CHRG-112hhrg71298
# assigning metadata
# CHRG-112hhrg82216
# assigning metadata
# CHRG-112hhrg79845
# assigning metadata
# CHRG-112hhrg67865
# assigning metadata
# CHRG-112shrg80612
# assigning metadata
# CHRG-112hhrg76043
# assigning metadata
# CHRG-112hhrg65940
# assigning metadata
# CHRG-112shrg67529
# assigning metadata
# CHRG-112hhrg80106
# assigning metadata
# CHRG-113hhrg91811
# assigning metadata
# CHRG-112shrg73346
# assigning metadata
# CHRG-112shrg76062
# assigning metadata
# CHRG-112shrg65733
# assigning metadata
# CHRG-112hhrg76218
# assigning metadata
# CHRG-112shrg66673
# assigning metadata
# CHRG-113hhrg87620
# assigning metadata
# CHRG-112hhrg70588
# assigning metadata
# CHRG-112hhrg70801
# assigning metadata
# CHRG-112hhrg68401
# assigning metadata
# CHRG-112hhrg67385
# assigning metadata
# CHRG-112hhrg66314
# assigning metadata
# CHRG-112hhrg65601
# assigning metadata
# CHRG-112hhrg76602
# assigning metadata
# CHRG-112hhrg72629
# assigning metadata
# CHRG-112shrg76131
# assigning metadata
# CHRG-112hhrg66967
# assigning metadata
# CHRG-112hhrg65109
# assigning metadata
# CHRG-112shrg92205
# assigning metadata
# assigning metadata
# CHRG-113hhrg86568
# assigning metadata
# CHRG-113hhrg80287
# assigning metadata
# CHRG-113shrg95795
# assigning metadata
# CHRG-113hhrg86549
# assigning metadata
# CHRG-113hhrg81766
# assigning metadata
# CHRG-113hhrg92630
# assigning metadata
# CHRG-113shrg93841
# assigning metadata
# CHRG-113hhrg80974
# assigning metadata
# CHRG-113hhrg82583
# assigning metadata
# CHRG-113hhrg89835
# assigning metadata
# CHRG-113hhrg80235
# assigning metadata
# CHRG-113shrg90895
# assigning metadata
# CHRG-113shrg91137
# assigning metadata
# CHRG-113shrg87564
# assigning metadata
# CHRG-113shrg82713
# assigning metadata
# CHRG-113jhrg95485
# assigning metadata
# CHRG-113shrg49104581
# assigning metadata
# CHRG-113shrg81959
# assigning metadata
# CHRG-113hhrg89809
# assigning metadata
# CHRG-113hhrg88827
# assigning metadata
# CHRG-113hhrg85091
# assigning metadata
# CHRG-113shrg24284
# assigning metadata
# CHRG-113shrg90791
# assigning metadata
# CHRG-113shrg99971
# assigning metadata
# CHRG-113hhrg82107
# assigning metadata
# CHRG-113hhrg88041
# assigning metadata
# CHRG-113hhrg87584
# assigning metadata
# CHRG-113hhrg81978
# assigning metadata
# CHRG-113hhrg80348
# assigning metadata
# CHRG-113hhrg20312
# CHRG-113hhrg78633
# assigning metadata
# CHRG-113shrg93028
# assigning metadata
# CHRG-113shrg82760
# assigning metadata
# CHRG-113hhrg81728
# assigning metadata
# CHRG-113shrg93949
# assigning metadata
# CHRG-113shrg82307
# assigning metadata
# CHRG-113hhrg88627
# assigning metadata
# CHRG-113shrg20361
# assigning metadata
# CHRG-113hhrg88145
# assigning metadata
# CHRG-113hhrg87331
# assigning metadata
# CHRG-113hhrg86556
# CHRG-113hhrg82466
# assigning metadata
# CHRG-113hhrg85741
# assigning metadata
# CHRG-113hhrg86925
# assigning metadata
# CHRG-113hhrg21121
# assigning metadata
# CHRG-113hhrg85673
# assigning metadata
# CHRG-113hhrg89596
# assigning metadata
# CHRG-113hhrg85686
# assigning metadata
# CHRG-113hhrg85314
# assigning metadata
# CHRG-113shrg97798
# assigning metadata
# CHRG-113shrg87798
# assigning metadata
# CHRG-113hhrg79726
# assigning metadata
# CHRG-113hhrg80191
# assigning metadata
# CHRG-113shrg89685
# assigning metadata
# CHRG-113shrg98202
# assigning metadata
# CHRG-113shrg95528
# assigning metadata
# CHRG-113hhrg88780
# assigning metadata
# CHRG-113shrg22278
# assigning metadata

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-5f0a17f5bf7b> in <module>
# ----> 1 parser.create_dataset('parsed')
#
# /mnt/c/Users/samue/Documents/hearings_lib/venv/lib/python3.8/site-packages/gpo_tools/parse.py in create_dataset(self, out_dir, out_name, min_token_length, min_doc_length, min_dic_count, additional_meta, additional_meta_labels)
#     178                         if len(doc) > min_doc_length:
#     179                             documents.append(doc)
# --> 180                             index_row = [','.join(row[key]) if type(row[key]) in (tuple, list) else row[key]
#     181                                          for key in index_keys]
#     182                             if additional_meta:
#
# /mnt/c/Users/samue/Documents/hearings_lib/venv/lib/python3.8/site-packages/gpo_tools/parse.py in <listcomp>(.0)
#     178                         if len(doc) > min_doc_length:
#     179                             documents.append(doc)
# --> 180                             index_row = [','.join(row[key]) if type(row[key]) in (tuple, list) else row[key]
#     181                                          for key in index_keys]
#     182                             if additional_meta:
#
# TypeError: sequence item 0: expected str instance, list found
